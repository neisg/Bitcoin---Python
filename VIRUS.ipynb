# %% [markdown]
# <a href="https://colab.research.google.com/github/neisg/Bitcoin---Python/blob/main/VIRUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *


speed(10)
color('red')
bgcolor('black')

b = 200
while b > 0:
  left(b)
  forward(b * 3)
  b = b - 1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
